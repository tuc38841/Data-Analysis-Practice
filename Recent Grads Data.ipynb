# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
raw_data_count = len(recent_grads)
recent_grads = recent_grads.dropna()
clean_data_count = len(recent_grads)
first_row = recent_grads.iloc[0]
raw_data_count = len(recent_grads)
first_row
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %% [markdown]
# Scatter Plots of Various Dataframe Relationships

# %%
ax = recent_grads.plot(x='Sample_size',y='Median',kind='scatter')
ax.set_title('Sample Size vs Median Salary')

# %%
ax = recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')
ax.set_title('Sample Size vs Unemployment Rate')

# %%
ax = recent_grads.plot(x='Full_time',y='Median',kind='scatter')
ax.set_title('Fulltime Employment vs Median Salary')

# %%
ax = recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')
ax.set_title('Share of Women vs Unemployment Rate')

# %%
ax = recent_grads.plot(x='Men',y='Median',kind='scatter')
ax.set_title('Share of Men vs Median Salary')

# %%
ax = recent_grads.plot(x='Women',y='Median',kind='scatter')
ax.set_title('Share of Women vs Median Salary')

# %% [markdown]
# Histograms to Show Distributions

# %%
recent_grads['Total'].hist(bins=20,range=(0,5000))

# %%
recent_grads['Median'].hist(bins=20)

# %%
recent_grads['Employed'].hist(bins=20)

# %%
recent_grads['Full_time'].hist(bins=20)

# %%
recent_grads['ShareWomen'].hist(bins=20)

# %%
recent_grads['Unemployment_rate'].hist(bins=20)

# %%
recent_grads['Men'].hist(bins=20)

# %%
recent_grads['Women'].hist(bins=20)

# %%
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1743dbcb38>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1743bfb2e8>,
# ...
#       dtype=object)

# %% [markdown]
# Compare share of women in top 10 majors vs bottom 10 majors

# %%
ax = recent_grads[:10]['ShareWomen'].plot(kind='bar')
ax.set_xticklabels(recent_grads[:10]['Major'])

# %%
ax = recent_grads[-10:]['ShareWomen'].plot(kind='bar')
ax.set_xticklabels(recent_grads[-10:]['Major'])

# %% [markdown]
# Unemployment rate in top 10 majors vs bottom 10 majors

# %%
ax = recent_grads[:10]['Unemployment_rate'].plot(kind='bar')
ax.set_xticklabels(recent_grads[:10]['Major'])

# %%
ax = recent_grads[-10:]['Unemployment_rate'].plot(kind='bar')
ax.set_xticklabels(recent_grads[-10:]['Major'])
